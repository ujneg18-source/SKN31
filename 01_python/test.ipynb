# %%
# 실행 단축키: shift + enter (실행하고 다음 셀로 이동)
#             control + enter(실행만 한다.)
# cell 위에 빈 cell을 만들기: a
# cell 아래 빈 cell을 만들기: b
# cell 삭제: dd (x: 잘라내기)
# cell을 파이썬 모드로 변경: y
# cell을 markdown 모드로 변경: m

1 + 1
# Out:
# 2

# %% [markdown]
# # 대제목
# 첫번째 줄
# 두번째 줄
# 라인을 나누려면 맨 뒤에 공백추가
# 세번째 줄
#
# ## 중제목
# 목록1
# * 1번
# * 2번
# * 3번
#
# 목록2
# - 1번
# - 2번
# - 3번
#     - 3-1
#     - 3-2
#
# 순서가 있는 목록
# 1. 가
# 1. 추가
# 1. 나
#     1. a
#     2. b
# 1. 다
#     - C
#     - D
#
# ### 소제목
# - 이태리체 *기울림*, _기울림체_
# - 볼드체   **진하게**, __진하게__
# - 이태리+볼드: ***둘합친것***, __둘합친것__
#
# #### 링크
# - [내용](url)
#     - [네이버](https://www.naver.com)
# - ![이미지내용](이미지 경로-url, 파일경로)
#
# ![이미지입니다](images\ch01_01.png)
#
# ![파이썬로고](https://www.python.org/static/img/python-logo.png)

# %%
num1 = 10

# %%
num2 = 20

# %%
num3 = num1 + num2

# %%
print(num3)
# Out:
# 30

# %%
a = 1
b = 2
c = a + b
print(c)
# Out:
# 3

# %%
1 + 20 * 3
# Out:
# 61
